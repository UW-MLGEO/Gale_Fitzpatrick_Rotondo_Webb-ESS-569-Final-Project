# %% [markdown]
# # Auto Machine Learning Model Selection and Hyperparameter Tuning
#
# This notebook uses the Python package `pycaret` to determine the best performing model for our regression purposes. After selecting the best model, we can then tune the hyperparameters to best optimize the models performance and physical understanding of the problem.
#
# First, we need to load the data. If the data is still in `.zip` format, we need to run the cell below to unzip it. Be sure to adjust `my_path` to the path you cloned this repository to.

# %%
# Replace with your path
my_path = '/global/u2/s/skygale/'

# %%
# Load the .nc file
import xarray as xr
import os

ds_path = os.path.join(my_path, 'MLGEO2024_SeaIcePrediction/data/ready_sic_sst_data.nc')
ds = xr.open_dataset(ds_path)
ds
# Out:
# <xarray.Dataset> Size: 85MB
# Dimensions:    (time: 46, latitude: 160, longitude: 1440)
# Coordinates:
#     number     int64 8B ...
#   * time       (time) datetime64[ns] 368B 1979-09-01 1980-09-01 ... 2024-09-01
#   * latitude   (latitude) float64 1kB 90.0 89.75 89.5 89.25 ... 50.75 50.5 50.25
#   * longitude  (longitude) float64 12kB -180.0 -179.8 -179.5 ... 179.5 179.8
#     expver     (time) <U4 736B ...
# Data variables:
#     sst        (time, latitude, longitude) float32 42MB ...
#     sic        (time, latitude, longitude) float32 42MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-25T20:05 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# For computational efficiency, we will use a specific region of the Arctic to compare models and regress on for sea surface temperature (SST). We will chose the Barents-Kara Sea, which lies north of Norway and Siberia. It's longitude and latitutde coordinates run from 30°–90°E and 65°–85°N, respectively.

# %%
# Select data for Barents-Kara Sea region
ds_sel = ds.sel(latitude=slice('85.01', '65'), longitude=slice('30', '90.01'))
ds_sel
# Out:
# <xarray.Dataset> Size: 18MB
# Dimensions:    (time: 46, latitude: 81, longitude: 600)
# Coordinates:
#     number     int64 8B ...
#   * time       (time) datetime64[ns] 368B 1979-09-01 1980-09-01 ... 2024-09-01
#   * latitude   (latitude) float64 648B 85.0 84.75 84.5 84.25 ... 65.5 65.25 65.0
#   * longitude  (longitude) float64 5kB 30.0 30.25 30.5 ... 179.2 179.5 179.8
#     expver     (time) <U4 736B ...
# Data variables:
#     sst        (time, latitude, longitude) float32 9MB ...
#     sic        (time, latitude, longitude) float32 9MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-25T20:05 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# Remove rows with missing values in the target column 'sic' (in case)
df = ds_sel.to_dataframe().reset_index()
df = df.dropna(subset=['sic'])

# %% [markdown]
# Now we can use `pycaret` to determine the best model for our purposes.

# %%
# Use pycaret to train and select models
from pycaret.regression import *

# Setup the data
s = setup(data=df, target='sic')

# Specify 8 models (trying all took too long)
model_list = ['dt', 'knn', 'lr', 'lasso',
             'ridge', 'rf', 'gbr', 'dummy']

# Run compare_models only with the specified models
best = compare_models(include=model_list)
# Out:
# <style type="text/css">
# #T_c8ed0_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c8ed0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8ed0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c8ed0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8ed0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8ed0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c8ed0_row0_col1" class="data row0 col1" >2955</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8ed0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c8ed0_row1_col1" class="data row1 col1" >sic</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8ed0_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c8ed0_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8ed0_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c8ed0_row3_col1" class="data row3 col1" >(1449736, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8ed0_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c8ed0_row4_col1" class="data row4 col1" >(1449736, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8ed0_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c8ed0_row5_col1" class="data row5 col1" >(1014815, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c8ed0_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c8ed0_row6_col1" class="data row6 col1" >(434921, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c8ed0_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c8ed0_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c8ed0_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_c8ed0_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c8ed0_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_c8ed0_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c8ed0_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_c8ed0_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c8ed0_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_c8ed0_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c8ed0_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_c8ed0_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c8ed0_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_c8ed0_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c8ed0_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_c8ed0_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c8ed0_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_c8ed0_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c8ed0_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_c8ed0_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c8ed0_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_c8ed0_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c8ed0_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_c8ed0_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c8ed0_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_c8ed0_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c8ed0_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_c8ed0_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c8ed0_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_c8ed0_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c8ed0_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c8ed0_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_c8ed0_row22_col1" class="data row22 col1" >8b15</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_393af th {
#   text-align: left;
# }
# #T_393af_row0_col0, #T_393af_row0_col6, #T_393af_row1_col0, #T_393af_row1_col1, #T_393af_row1_col2, #T_393af_row1_col3, #T_393af_row1_col4, #T_393af_row1_col5, #T_393af_row1_col6, #T_393af_row2_col0, #T_393af_row2_col1, #T_393af_row2_col2, #T_393af_row2_col3, #T_393af_row2_col4, #T_393af_row2_col5, #T_393af_row3_col0, #T_393af_row3_col1, #T_393af_row3_col2, #T_393af_row3_col3, #T_393af_row3_col4, #T_393af_row3_col5, #T_393af_row3_col6, #T_393af_row4_col0, #T_393af_row4_col1, #T_393af_row4_col2, #T_393af_row4_col3, #T_393af_row4_col4, #T_393af_row4_col5, #T_393af_row4_col6, #T_393af_row5_col0, #T_393af_row5_col1, #T_393af_row5_col2, #T_393af_row5_col3, #T_393af_row5_col4, #T_393af_row5_col5, #T_393af_row5_col6, #T_393af_row6_col0, #T_393af_row6_col1, #T_393af_row6_col2, #T_393af_row6_col3, #T_393af_row6_col4, #T_393af_row6_col5, #T_393af_row6_col6, #T_393af_row7_col0, #T_393af_row7_col1, #T_393af_row7_col2, #T_393af_row7_col3, #T_393af_row7_col4, #T_393af_row7_col5, #T_393af_row7_col6 {
#   text-align: left;
# }
# #T_393af_row0_col1, #T_393af_row0_col2, #T_393af_row0_col3, #T_393af_row0_col4, #T_393af_row0_col5, #T_393af_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_393af_row0_col7, #T_393af_row1_col7, #T_393af_row2_col7, #T_393af_row3_col7, #T_393af_row4_col7, #T_393af_row5_col7, #T_393af_row7_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_393af_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_393af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_393af_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_393af_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_393af_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_393af_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_393af_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_393af_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_393af_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_393af_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_393af_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_393af_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_393af_row0_col1" class="data row0 col1" >0.0042</td>
#       <td id="T_393af_row0_col2" class="data row0 col2" >0.0001</td>
#       <td id="T_393af_row0_col3" class="data row0 col3" >0.0122</td>
#       <td id="T_393af_row0_col4" class="data row0 col4" >0.9991</td>
#       <td id="T_393af_row0_col5" class="data row0 col5" >0.0091</td>
#       <td id="T_393af_row0_col6" class="data row0 col6" >0.1888</td>
#       <td id="T_393af_row0_col7" class="data row0 col7" >8.3600</td>
#     </tr>
#     <tr>
#       <th id="T_393af_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_393af_row1_col0" class="data row1 col0" >K Neighbors Regressor</td>
#       <td id="T_393af_row1_col1" class="data row1 col1" >0.0060</td>
#       <td id="T_393af_row1_col2" class="data row1 col2" >0.0002</td>
#       <td id="T_393af_row1_col3" class="data row1 col3" >0.0154</td>
#       <td id="T_393af_row1_col4" class="data row1 col4" >0.9986</td>
#       <td id="T_393af_row1_col5" class="data row1 col5" >0.0111</td>
#       <td id="T_393af_row1_col6" class="data row1 col6" >0.1910</td>
#       <td id="T_393af_row1_col7" class="data row1 col7" >1.4560</td>
#     </tr>
#     <tr>
#       <th id="T_393af_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_393af_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#       <td id="T_393af_row2_col1" class="data row2 col1" >0.0051</td>
#       <td id="T_393af_row2_col2" class="data row2 col2" >0.0003</td>
#       <td id="T_393af_row2_col3" class="data row2 col3" >0.0168</td>
#       <td id="T_393af_row2_col4" class="data row2 col4" >0.9983</td>
#       <td id="T_393af_row2_col5" class="data row2 col5" >0.0126</td>
#       <td id="T_393af_row2_col6" class="data row2 col6" >0.1510</td>
#       <td id="T_393af_row2_col7" class="data row2 col7" >2.3870</td>
#     </tr>
#     <tr>
#       <th id="T_393af_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_393af_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_393af_row3_col1" class="data row3 col1" >0.0336</td>
#       <td id="T_393af_row3_col2" class="data row3 col2" >0.0030</td>
#       <td id="T_393af_row3_col3" class="data row3 col3" >0.0548</td>
#       <td id="T_393af_row3_col4" class="data row3 col4" >0.9823</td>
#       <td id="T_393af_row3_col5" class="data row3 col5" >0.0380</td>
#       <td id="T_393af_row3_col6" class="data row3 col6" >1.9994</td>
#       <td id="T_393af_row3_col7" class="data row3 col7" >8.5680</td>
#     </tr>
#     <tr>
#       <th id="T_393af_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_393af_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_393af_row4_col1" class="data row4 col1" >0.2194</td>
#       <td id="T_393af_row4_col2" class="data row4 col2" >0.0670</td>
#       <td id="T_393af_row4_col3" class="data row4 col3" >0.2588</td>
#       <td id="T_393af_row4_col4" class="data row4 col4" >0.6065</td>
#       <td id="T_393af_row4_col5" class="data row4 col5" >0.1949</td>
#       <td id="T_393af_row4_col6" class="data row4 col6" >25.1512</td>
#       <td id="T_393af_row4_col7" class="data row4 col7" >1.1210</td>
#     </tr>
#     <tr>
#       <th id="T_393af_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_393af_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_393af_row5_col1" class="data row5 col1" >0.2194</td>
#       <td id="T_393af_row5_col2" class="data row5 col2" >0.0670</td>
#       <td id="T_393af_row5_col3" class="data row5 col3" >0.2588</td>
#       <td id="T_393af_row5_col4" class="data row5 col4" >0.6065</td>
#       <td id="T_393af_row5_col5" class="data row5 col5" >0.1949</td>
#       <td id="T_393af_row5_col6" class="data row5 col6" >25.1512</td>
#       <td id="T_393af_row5_col7" class="data row5 col7" >1.0730</td>
#     </tr>
#     <tr>
#       <th id="T_393af_level0_row6" class="row_heading level0 row6" >lasso</th>
#       <td id="T_393af_row6_col0" class="data row6 col0" >Lasso Regression</td>
#       <td id="T_393af_row6_col1" class="data row6 col1" >0.3259</td>
#       <td id="T_393af_row6_col2" class="data row6 col2" >0.1247</td>
#       <td id="T_393af_row6_col3" class="data row6 col3" >0.3532</td>
#       <td id="T_393af_row6_col4" class="data row6 col4" >0.2670</td>
#       <td id="T_393af_row6_col5" class="data row6 col5" >0.2545</td>
#       <td id="T_393af_row6_col6" class="data row6 col6" >26.9502</td>
#       <td id="T_393af_row6_col7" class="data row6 col7" >1.0460</td>
#     </tr>
#     <tr>
#       <th id="T_393af_level0_row7" class="row_heading level0 row7" >dummy</th>
#       <td id="T_393af_row7_col0" class="data row7 col0" >Dummy Regressor</td>
#       <td id="T_393af_row7_col1" class="data row7 col1" >0.3940</td>
#       <td id="T_393af_row7_col2" class="data row7 col2" >0.1702</td>
#       <td id="T_393af_row7_col3" class="data row7 col3" >0.4125</td>
#       <td id="T_393af_row7_col4" class="data row7 col4" >-0.0000</td>
#       <td id="T_393af_row7_col5" class="data row7 col5" >0.2976</td>
#       <td id="T_393af_row7_col6" class="data row7 col6" >27.4306</td>
#       <td id="T_393af_row7_col7" class="data row7 col7" >1.0490</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Since we have compared all of the models, we can see that the best model is **Random Forest Regressor**. The total time taken to evaluate for the best model was 50 minutes. We can now evaluate our model using the built in function `evaluate_model`.

# %%
# Show model evaluation
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# Finally, we can save and plot the best model for future use and visual checks.

# %%
# Plot the model
plot_model(best, plot='error')

# Save the model
save_model(best, 'best_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('date_feature_extractor',
#                   TransformerWrapper(include=['time'],
#                                      transformer=ExtractDateTimeFeatures())),
#                  ('numerical_imputer',
#                   TransformerWrapper(include=['latitude', 'longitude', 'number',
#                                               'sst'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['expver'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   TransformerWrapper(include=['expver'],
#                                      transformer=OrdinalEncoder(cols=['expver'],
#                                                                 handle_missing='return_nan',
#                                                                 mapping=[{'col': 'expver',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': 0001    0
#  0005    1
#  NaN    -1
#  dtype: int64}]))),
#                  ('trained_model',
#                   RandomForestRegressor(n_jobs=-1, random_state=2955))]),
#  'best_model.pkl')

# %% [markdown]
# For example, let's load the model and make predictions.

# %%
# Load the model
loaded_model = load_model('best_model')

# Make predictions
predictions = predict_model(loaded_model, df)

print(predictions)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_e6f46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6f46_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e6f46_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e6f46_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e6f46_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e6f46_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e6f46_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e6f46_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6f46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6f46_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_e6f46_row0_col1" class="data row0 col1" >0.0022</td>
#       <td id="T_e6f46_row0_col2" class="data row0 col2" >0.0001</td>
#       <td id="T_e6f46_row0_col3" class="data row0 col3" >0.0073</td>
#       <td id="T_e6f46_row0_col4" class="data row0 col4" >0.9997</td>
#       <td id="T_e6f46_row0_col5" class="data row0 col5" >0.0055</td>
#       <td id="T_e6f46_row0_col6" class="data row0 col6" >0.0969</td>
#     </tr>
#   </tbody>
# </table>
#               time  latitude  longitude  number expver         sst       sic  \
# 0       1979-09-01      85.0      30.00       0   0001  271.459961  0.809814
# 1       1979-09-01      85.0      30.25       0   0001  271.459961  0.808502
# 2       1979-09-01      85.0      30.50       0   0001  271.459961  0.807190
# 3       1979-09-01      85.0      30.75       0   0001  271.459961  0.805878
# 4       1979-09-01      85.0      31.00       0   0001  271.459961  0.804565
# ...            ...       ...        ...     ...    ...         ...       ...
# 2235036 2024-09-01      65.0      39.00       0   0005  287.400391  0.000000
# 2235037 2024-09-01      65.0      39.25       0   0005  287.504883  0.000000
# 2235038 2024-09-01      65.0      39.50       0   0005  287.649414  0.000000
# 2235039 2024-09-01      65.0      39.75       0   0005  287.725586  0.000000
# 2235040 2024-09-01      65.0      40.00       0   0005  287.796875  0.000000
#
#          prediction_label
# 0                0.808033
# 1                0.807153
# 2                0.806266
# 3                0.805699
# 4                0.802666
# ...                   ...
# 2235036          0.000000
# 2235037          0.000000
# 2235038          0.000000
# 2235039          0.000000
# 2235040          0.000000
#
# [1449736 rows x 8 columns]
